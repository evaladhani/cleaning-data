# %% [markdown]
# # Cleaning Data Exercises
#
# For the exercises, you will be cleaning data in your chosen data set. [Towards Data Science](https://towardsdatascience.com/data-cleaning-in-python-the-ultimate-guide-2020-c63b88bf0a0d) outlines the steps we should take to clean data using a different data set from Kaggle. While you should use this article as a reference, make sure not to copy paste as the two data sets are very different!
#
# To start cleaning data, we first need to create a dataframe from the CSV and print out any relevant info to make sure our dataframe is ready to go.

# %%
# Import pandas and any other libraries you need here. HINT: Check out the article to see what they imported to get started!
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# Create a new dataframe from your CSV
df = pd.read_csv("Womens Clothing E-Commerce Reviews.csv")

# %%
# Print out any information you need to understand your dataframe
df.describe()
# Out:
#                  ID   Clothing ID           Age        Rating  \
# count  23486.000000  23486.000000  23486.000000  23486.000000
# mean   11742.500000    918.118709     43.198544      4.196032
# std     6779.968547    203.298980     12.279544      1.110031
# min        0.000000      0.000000     18.000000      1.000000
# 25%     5871.250000    861.000000     34.000000      4.000000
# 50%    11742.500000    936.000000     41.000000      5.000000
# 75%    17613.750000   1078.000000     52.000000      5.000000
# max    23485.000000   1205.000000     99.000000      5.000000
#
#        Recommended IND  Positive Feedback Count
# count     23486.000000             23486.000000
# mean          0.822362                 2.535936
# std           0.382216                 5.702202
# min           0.000000                 0.000000
# 25%           1.000000                 0.000000
# 50%           1.000000                 1.000000
# 75%           1.000000                 3.000000
# ...

# %%
df.head(20)
# Out:
#     ID  Clothing ID  Age                                              Title  \
# 0    0          767   33                                                NaN
# 1    1         1080   34                                                NaN
# 2    2         1077   60                            Some major design flaws
# 3    3         1049   50                                   My favorite buy!
# 4    4          847   47                                   Flattering shirt
# 5    5         1080   49                            Not for the very petite
# 6    6          858   39                               Cagrcoal shimmer fun
# 7    7          858   39               Shimmer, surprisingly goes with lots
# 8    8         1077   24                                         Flattering
# 9    9         1077   34                                  Such a fun dress!
# 10  10         1077   53       Dress looks like it's made of cheap material
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Clothing ID', 'Age', 'Title', 'Review Text', 'Rating',
#        'Recommended IND', 'Positive Feedback Count', 'Division Name',
#        'Department Name', 'Class Name'],
#       dtype='object')

# %%
df.shape
# Out:
# (23486, 11)

# %% [markdown]
# Now you have a dataframe set up, you are ready to dive in and start cleaning!

# %% [markdown]
# ## Missing Data
#
# In the Towards Data Science article, they list 3 techniques for detecting any missing data frame. Try all three before deciding on a way to solve any missing data issues.

# %%
# Plot a heatmap of any missing data

#cols = df.columns[:30] # first 30 columns
#colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
#sns.heatmap(df[cols].isnull(), cmap=sns.color_palette(colours))

cols = df.columns[:30]
colors = ["#000099", "#ffff00"]
sns.heatmap(df[cols].isnull(), cmap=sns.color_palette(colors))

#Findings: Title has a ton of missing values and Review Text has a couple
# Out:
# <AxesSubplot:>

# %%
# Try out a missing data percentage list! 

# if it's a larger dataset and the visualization takes too long can do this.
# % of missing.
#for col in df.columns:
#    pct_missing = np.mean(df[col].isnull())
#    print('{} - {}%'.format(col, round(pct_missing*100)))

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} = {}%'.format(col, round(pct_missing*100)))
# Out:
# ID = 0%
# Clothing ID = 0%
# Age = 0%
# Title = 16%
# Review Text = 4%
# Rating = 0%
# Recommended IND = 0%
# Positive Feedback Count = 0%
# Division Name = 0%
# Department Name = 0%
# Class Name = 0%

# %%
# Plot a missing data histogram

# first create missing indicator for features with missing data

for col in df.columns:
    missing = df[col].isnull()
    num_missing = np.sum(missing)
    
    if num_missing > 0:
        print('created missing indicator for: {}'.format(col))
        df['{}_ismissing'.format(col)] = missing

#then based on the indicator, plot the histogram of missing values

ismissing_cols = [col for col in df.columns if 'ismissing' in col]
df['num_missing'] = df[ismissing_cols].sum(axis=1)

df['num_missing'].value_counts().reset_index().sort_values(by='index').plot.bar(x='index', y='num_missing')
# Out:
# created missing indicator for: Title
# created missing indicator for: Review Text
# created missing indicator for: Division Name
# created missing indicator for: Department Name
# created missing indicator for: Class Name
# <AxesSubplot:xlabel='index'>

# %% [markdown]
# Now that you have tried all 3 techniques for detecting missing data, did you find any? Reading through the article, which solution do you think will help you clean the data set and handle the missing data? Try out your solution below!

# %%
# Handle any missing data in your dataframe.

# drop rows with a lot of missing values.

ind_missing = df[df['num_missing'] > 0].index
df_less_missing_rows = df.drop(ind_missing, axis=0)

df_less_missing_rows.head(50)
# Out:
#     ID  Clothing ID  Age                                              Title  \
# 2    2         1077   60                            Some major design flaws
# 3    3         1049   50                                   My favorite buy!
# 4    4          847   47                                   Flattering shirt
# 5    5         1080   49                            Not for the very petite
# 6    6          858   39                               Cagrcoal shimmer fun
# 7    7          858   39               Shimmer, surprisingly goes with lots
# 8    8         1077   24                                         Flattering
# 9    9         1077   34                                  Such a fun dress!
# 10  10         1077   53       Dress looks like it's made of cheap material
# 12  12         1095   53                                         Perfect!!!
# 13  13          767   44                                           Runs big
# ...

# %% [markdown]
# ## Irregular Data
#
# With missing data out of the way, turn your attention to any outliers. Just as we did for missing data, we first need to detect the outliers. The article outlines the top techniques for finding outliers in a dataset.

# %%
# Plot a histogram to see if there are any outliers.

# histogram of life_sq.
df_less_missing_rows['Positive Feedback Count'].hist(bin=100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/gr/m_4q_mbn41l1317rrcqyyj880000gn/T/ipykernel_15773/3220198234.py in <module>
#       2
#       3 # histogram of life_sq.
# ----> 4 df_less_missing_rows['Positive Feedback Count'].hist(bin=100)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#      98     """
#      99     plot_backend = _get_plot_backend(backend)
# --> 100     return plot_backend.hist_series(
#     101         self,
#     102         by=by,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/hist.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, legend, **kwds)
#     352         if legend:
#     353             kwds["label"] = self.name
# ...

# %%
# Use the describe() method
df_less_missing_rows['Positive Feedback Count'].describe()
# Out:
# count    19662.000000
# mean         2.652477
# std          5.834285
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          3.000000
# max        122.000000
# Name: Positive Feedback Count, dtype: float64

# %%
# Plot a bar chart
# bar chart -  distribution of a categorical variable
df_less_missing_rows['Positive Feedback Count'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Which of the three techniques helped you find any outliers? Now that you have found outliers, what will you do to solve the problem?

# %%
# Handle any outliers in your dataframe

# Don't want to use any of the solutions because it will show skewed data. We don't want to remove missing data or replace or completely remove the column.

# %% [markdown]
# ## Unnecessary Data
#
# Unnecessary data could be duplicates, irrelevant, or any uninformative data. Dive into each type of unnecessary data to see if there is any in the data set. Make sure to make note of how you would handle each type of unnecessary data.

# %%
# Look for any irrelevant data in the dataframe. How will you handle it?

#num_rows = len(df.index)
#low_information_cols = [] #

#for col in df.columns:
#    cnts = df[col].value_counts(dropna=False)
#    top_pct = (cnts/num_rows).iloc[0]
    
#    if top_pct > 0.95:
#        low_information_cols.append(col)
#        print('{0}: {1:.5f}%'.format(col, top_pct*100))
#        print(cnts)
#        print()

num_rows = len(df_less_missing_rows.index)
low_information_cols = []

for col in df_less_missing_rows.columns:
    cnts = df_less_missing_rows[col].value_counts(dropna=False)
    top_pct = (cnts/num_rows).iloc[0]
    
    if top_pct > 0.95:
        low_information_cols.append(col)
        print('{0}: {1:.5f}%'.format(col, top_pct*100))
        print(cnts)
        print()
# Out:
# Title_ismissing: 100.00000%
# False    19662
# Name: Title_ismissing, dtype: int64
#
# Review Text_ismissing: 100.00000%
# False    19662
# Name: Review Text_ismissing, dtype: int64
#
# Division Name_ismissing: 100.00000%
# False    19662
# Name: Division Name_ismissing, dtype: int64
#
# Department Name_ismissing: 100.00000%
# False    19662
# Name: Department Name_ismissing, dtype: int64
#
# Class Name_ismissing: 100.00000%
# False    19662
# Name: Class Name_ismissing, dtype: int64
#
# num_missing: 100.00000%
# 0    19662
# Name: num_missing, dtype: int64

# %%
df_less_missing_rows.shape
# Out:
# (19662, 17)

# %%
df_less_missing_rows.head(50)
# Out:
#     ID  Clothing ID  Age                                              Title  \
# 2    2         1077   60                            Some major design flaws
# 3    3         1049   50                                   My favorite buy!
# 4    4          847   47                                   Flattering shirt
# 5    5         1080   49                            Not for the very petite
# 6    6          858   39                               Cagrcoal shimmer fun
# 7    7          858   39               Shimmer, surprisingly goes with lots
# 8    8         1077   24                                         Flattering
# 9    9         1077   34                                  Such a fun dress!
# 10  10         1077   53       Dress looks like it's made of cheap material
# 12  12         1095   53                                         Perfect!!!
# 13  13          767   44                                           Runs big
# ...

# %%
# Look for duplicates. How will you handle any duplicates?

# we know that column 'id' is unique, but what if we drop it?
df_dedupped = df_less_missing_rows.drop('ID', axis=1).drop_duplicates()

# there were duplicate rows
print(df_less_missing_rows.shape)
print(df_dedupped.shape)

df_dedupped = df_less_missing_rows
# Out:
# (19662, 17)
# (19662, 16)

# %%
df_dedupped = df_dedupped.drop('Title_ismissing', axis=1)
df_dedupped = df_dedupped.drop('Division Name_ismissing', axis=1)
df_dedupped = df_dedupped.drop('Department Name_ismissing', axis=1)
df_dedupped = df_dedupped.drop('Class Name_ismissing', axis=1)
df_dedupped = df_dedupped.drop('num_missing', axis=1)
df_dedupped = df_dedupped.drop('Review Text_ismissing', axis=1)

# %%
df_dedupped.head()

df_dedupped.columns
# Out:
# Index(['ID', 'Clothing ID', 'Age', 'Title', 'Review Text', 'Rating',
#        'Recommended IND', 'Positive Feedback Count', 'Division Name',
#        'Department Name', 'Class Name'],
#       dtype='object')

# %%
#Remove key features duplicates

#df.fillna(-999).groupby(key)['id'].count().sort_values(ascending=False).head(20)

key = ['Title', 'Review Text']
df_dedupped.fillna(-999).groupby(key)['ID'].count().sort_values(ascending=False).head(20)
# Out:
# Title                                              Review Text
# Love retailer bathing suits!                       Perfect fit and i've gotten so many compliments. i buy all my suits from here now!                                                                                                                                                                                                                                                                                                                                                                                                                                        3
# ...

# %%
#Remove duplicate entries

df_dedupped2 = df_dedupped.drop_duplicates(subset=key)

print(df.shape)
print(df_dedupped2.shape)

df_dedupped2.fillna(-999).groupby(key)['ID'].count().sort_values(ascending=False).head(20)
# Out:
# (23486, 17)
# (19658, 11)
# Title                                              Review Text
# "beach business"                                   Great for the beachy business look. classy, but immensely comfortable. i feel like i look sharp without having to sit poker-straight.                                                                                                                                                                                                                                                                                                                                                                                     1
# ...

# %%
# Think about what data in the dataframe may be uninformative. Make note here of what situations may render data uninformative and how you would handle it?

# %% [markdown]
# ## Inconsistent Data
#
# Inconsistent data is anything that messes with your model. This is likely due to inconsistent formatting and can be addressed by re-formatting all values in a column or row.

# %%
# Try to convert all the strings in a column to lower or upper case. 


# make everything lower case.
df_dedupped2['Title'] = df_dedupped2['Title'].str.lower()
df_dedupped2['Title'].value_counts(dropna=False)

df_dedupped2['Review Text'] = df_dedupped2['Review Text'].str.lower()
df_dedupped2['Review Text'].value_counts(dropna=False)
# Out:
# /var/folders/gr/m_4q_mbn41l1317rrcqyyj880000gn/T/ipykernel_15773/3259833136.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dedupped2['Title'] = df_dedupped2['Title'].str.lower()
# /var/folders/gr/m_4q_mbn41l1317rrcqyyj880000gn/T/ipykernel_15773/3259833136.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dedupped2['Review Text'] = df_dedupped2['Review Text'].str.lower()
# ...

# %%
df_dedupped2.head(50)
# Out:
#     ID  Clothing ID  Age                                              Title  \
# 2    2         1077   60                            some major design flaws
# 3    3         1049   50                                   my favorite buy!
# 4    4          847   47                                   flattering shirt
# 5    5         1080   49                            not for the very petite
# 6    6          858   39                               cagrcoal shimmer fun
# 7    7          858   39               shimmer, surprisingly goes with lots
# 8    8         1077   24                                         flattering
# 9    9         1077   34                                  such a fun dress!
# 10  10         1077   53       dress looks like it's made of cheap material
# 12  12         1095   53                                         perfect!!!
# 13  13          767   44                                           runs big
# ...

# %%
df_dedupped2['Division Name'].unique()
# Out:
# array(['General', 'General Petite', 'Initmates'], dtype=object)

# %%
#df_dedupped2['Division Name'] = df_dedupped2['Division Name'].str.replace('Initmates', 'Intimates')

df_dedupped2['Division Name'].replace('Initmates', 'Intimates')
# Out:
# 2               General
# 3        General Petite
# 4               General
# 5               General
# 6        General Petite
#               ...
# 23481    General Petite
# 23482    General Petite
# 23483    General Petite
# 23484           General
# 23485    General Petite
# Name: Division Name, Length: 19658, dtype: object

# %%
df_dedupped2['Division Name'].unique()
# Out:
# array(['General', 'General Petite', 'Intimates'], dtype=object)
